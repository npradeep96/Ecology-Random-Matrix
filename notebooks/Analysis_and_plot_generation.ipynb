# %%
from matplotlib import pyplot as plt
import numpy as np
import h5py
import os
import re

# %%
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.rcParams['xtick.labelsize']=20
plt.rcParams['ytick.labelsize']=20
plt.rcParams['font.size']=20
plt.rcParams["text.usetex"]=True

# %% [markdown]
# ## Plot probability vs N and C

# %% [markdown]
# ### Random Matrix

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/random/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ### Random predator-prey

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ### Mutualism

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mutualism/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contour(N_list, C_list, probability_of_stability, levels=[0.5,])
# cbar = fig.colorbar(contour)
# cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# Text(0, 0.5, '$C$')

# %% [markdown]
# ### Competition

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/competition/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ## Predator prey cascade

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey_cascade/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ## Predator prey Niche model

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey_niche/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ### Bipartite mutualism

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/bipartite_mutualism/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ### Mixture model

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mixed/'
C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]
probability_of_stability = np.zeros([len(C_list), len(N_list)])

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for i in range(len(C_list)):
    for j in range(len(N_list)):
        analysis_file_name = target_directory + subdirectory_name.format(C_val=C_list[i], 
                                                                     N_val=N_list[j]) + analysis_file
        with open(analysis_file_name, 'r') as f:
            for line in f.readlines():
                if re.match(r'probability of stability\, *', line) != None:
                    probability_of_stability[i,j] = float(line.split(',')[1])

# %%
fig,axs = plt.subplots(1,1,figsize=(6,6))

contour = axs.contourf(N_list, C_list, probability_of_stability)
cbar = fig.colorbar(contour)
cbar.set_clim()

axs.set_xlabel(r'$N$')
axs.set_ylabel(r'$C$')
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   """
# Text(0, 0.5, '$C$')

# %% [markdown]
# ### Adding predators

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mixture_add_predator/'
C_list = [0.05, 0.22, 0.5]
sigma_list = [0.1, 0.3, 0.5, 0.8, 1.0, 2.0, 3.0, 4.0]
N_list = [5.0, 25.0, 50.0, 75.0, 100.0, 150.0, 200.0, 250.0, 300.0, 350.0, 400.0]

probability_dict = {}

subdirectory_name = 'C_0.22_N_50.0_sigma_1.0_d_4.0_C_add_{C_val}_N_add_{N_val}_sigma_add_{sigma_val}/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for C in C_list:
    probability_of_stability = np.zeros([len(sigma_list), len(N_list)])
    for i in range(len(sigma_list)):
        for j in range(len(N_list)):
            analysis_file_name = target_directory + subdirectory_name.format(sigma_val=sigma_list[i], 
                                                                         N_val=N_list[j], C_val=C) + analysis_file
            with open(analysis_file_name, 'r') as f:
                for line in f.readlines():
                    if re.match(r'probability of stability\, *', line) != None:
                        probability_of_stability[i,j] = float(line.split(',')[1])
                        
    probability_dict[C] = probability_of_stability

# %%
fig,axs = plt.subplots(1,3,figsize=(20,6))
ratio = [0.25, 1.0, 2.0]

for i in range(len(C_list)):
    contour = axs[i].contourf(np.array(N_list)/50.0, sigma_list, probability_dict[C_list[i]])
    axs[i].set_xlabel(r'Ratio of predators ($N_{p}/N_{b}$)')
    axs[i].set_title(r'$C_p/C_b$ = ' + str(ratio[i]))
    
axs[0].set_ylabel(r'Ratio of interaction strength ($\sigma_{p}/\sigma_{b})$')
cbar = fig.colorbar(contour)
cbar.set_clim()
plt.show()
plt.close()
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)

fig,axs = plt.subplots(1,2,figsize=(15,6))
axs[0].plot(np.array(N_list)/50.0, probability_dict[0.22][3][:], '-ko' )
axs[0].plot(np.array(N_list)/50.0, probability_dict[0.22][3][:], '-ko' )
axs[0].set_ylabel('Probability of Stability')
axs[0].set_xlabel(r'Ratio of predators ($N_{p}/N_{b}$)')

axs[1].plot(sigma_list, probability_dict[0.22][:,4], '-ko' )
axs[1].set_ylabel('Probability of Stability')
axs[1].set_xlabel(r'Ratio of interaction strength ($\sigma_{p}/\sigma_{b})$')

plt.show()
plt.close()
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
target_directory = '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mixture_add_predator/'
C_list = [0.02, 0.12, 0.25]
sigma_list = [0.1, 0.3, 0.5, 0.8, 1.0, 2.0, 3.0, 4.0]
N_list = [10.0, 50.0, 100.0, 150.0, 200.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0]

probability_dict = {}

subdirectory_name = 'C_0.12_N_100.0_sigma_1.0_d_4.0_C_add_{C_val}_N_add_{N_val}_sigma_add_{sigma_val}/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for C in C_list:
    probability_of_stability = np.zeros([len(sigma_list), len(N_list)])
    for i in range(len(sigma_list)):
        for j in range(len(N_list)):
            analysis_file_name = target_directory + subdirectory_name.format(sigma_val=sigma_list[i], 
                                                                         N_val=N_list[j], C_val=C) + analysis_file
            with open(analysis_file_name, 'r') as f:
                for line in f.readlines():
                    if re.match(r'probability of stability\, *', line) != None:
                        probability_of_stability[i,j] = float(line.split(',')[1])
                        
    probability_dict[C] = probability_of_stability

# %%
fig,axs = plt.subplots(1,3,figsize=(20,6))
ratio = [0.25, 1.0, 2.0]

for i in range(len(C_list)):
    contour = axs[i].contourf(np.array(N_list)/50.0, sigma_list, probability_dict[C_list[i]])
    axs[i].set_xlabel(r'Ratio of predators ($N_{p}/N_{b}$)')
    axs[i].set_title(r'$C_p/C_d$ = ' + str(ratio[i]))
    
axs[0].set_ylabel(r'Ratio of interaction strength ($\sigma_{p}/\sigma_{b})$')
cbar = fig.colorbar(contour)
cbar.set_clim()
plt.show()
plt.close()
# axs.set_xlim([0.06,0.22])
# axs.set_ylim([0,0.25])

# plt.savefig('20220206 - Plots for paper/cmax_phi_p_condensate.svg', format='svg', dpi = 600)
# Out:
# /home/npradeep96/miniconda3/envs/random-matrix/lib/python3.6/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## Plots for report

# %% [markdown]
# ### Comparing random graph models for different interaction types

# %%
target_directory_list = {'random': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/random/',
                         'predator prey': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey/',
                         'competition': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/competition/',
                         'mutualism': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mutualism/',
                         'mixed': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mixed/'}

C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]

probability_dict = {}

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for model, directory in target_directory_list.items():
    probability_of_stability = np.zeros([len(C_list), len(N_list)])
    for i in range(len(C_list)):
        for j in range(len(N_list)):
            analysis_file_name = directory + subdirectory_name.format(C_val=C_list[i], 
                                                                         N_val=N_list[j]) + analysis_file
            with open(analysis_file_name, 'r') as f:
                for line in f.readlines():
                    if re.match(r'probability of stability\, *', line) != None:
                        probability_of_stability[i,j] = float(line.split(',')[1])
                        
    probability_dict[model] = probability_of_stability

# %%
from matplotlib.lines import Line2D

fig,axs = plt.subplots(1,1,figsize=(6,6))

graph_dict = {'random': ['solid','k'],
             'predator prey': ['solid', 'r'],
             'competition': ['dotted', 'b'],
             'mutualism': ['dashed', 'b'],
             'mixed': ['dashdot', 'b']}

for model in target_directory_list.keys():
    contour = axs.contour(N_list, C_list, probability_dict[model], 
                          colors=(graph_dict[model][1]), linestyles=graph_dict[model][0], 
                          levels=[0.5,])
    # axs.clabel(contour, contour.levels[::2], inline=True, fmt=[model])

lines = [Line2D([0], [0], color='k', linewidth=3, linestyle='-'),
         Line2D([0], [0], color='r', linewidth=3, linestyle='-'), 
         Line2D([0], [0], color='b', linewidth=3, linestyle=':'), 
         Line2D([0], [0], color='b', linewidth=3, linestyle='--'), 
         Line2D([0], [0], color='b', linewidth=3, linestyle='-.')]
labels = ['random', 'predator prey', 'competition', 'mutualism', 'mixed']
axs.legend(lines, labels, loc='center left', bbox_to_anchor=(1, 0.5))    
axs.set_xlabel(r'Number of species ($N_d$)')
axs.set_ylabel(r'Connectance ($C_d$)')
# Out:
# Text(0, 0.5, 'Connectance ($C_d$)')

# %% [markdown]
# ### Comparing different predator prey topologies

# %%
target_directory_list = {'random': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey/',
                         'niche': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey_niche/',
                         'cascade': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/predator_prey_cascade/'}

C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]

probability_dict = {}

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for model, directory in target_directory_list.items():
    probability_of_stability = np.zeros([len(C_list), len(N_list)])
    for i in range(len(C_list)):
        for j in range(len(N_list)):
            analysis_file_name = directory + subdirectory_name.format(C_val=C_list[i], 
                                                                         N_val=N_list[j]) + analysis_file
            with open(analysis_file_name, 'r') as f:
                for line in f.readlines():
                    if re.match(r'probability of stability\, *', line) != None:
                        probability_of_stability[i,j] = float(line.split(',')[1])
                        
    probability_dict[model] = probability_of_stability

# %%
from matplotlib.lines import Line2D

fig,axs = plt.subplots(1,1,figsize=(6,6))

graph_dict = {'random': ['solid','k'],
             'niche': ['solid', 'r'],
             'cascade': ['solid', 'b']}

for model in target_directory_list.keys():
    contour = axs.contour(N_list, C_list, probability_dict[model], 
                          colors=(graph_dict[model][1]), linestyles=graph_dict[model][0], 
                          levels=[0.5,])
    # axs.clabel(contour, contour.levels[::2], inline=True, fmt=[model])

lines = [Line2D([0], [0], color='k', linewidth=3, linestyle='-'),
         Line2D([0], [0], color='r', linewidth=3, linestyle='-'), 
         Line2D([0], [0], color='b', linewidth=3, linestyle='-')]
labels = ['random', 'niche', 'cascade']
axs.legend(lines, labels, loc='center left', bbox_to_anchor=(1, 0.5))    
axs.set_xlabel(r'Number of species ($N_d$)')
axs.set_ylabel(r'Connectance ($C_d$)')
# Out:
# Text(0, 0.5, 'Connectance ($C_d$)')

# %% [markdown]
# ### Comparing different mutualism topologies

# %%
target_directory_list = {'random': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/mutualism/',
                         'bipartite': '/home/npradeep96/Projects/Ecology-Random-Matrix/outputs/bipartite_mutualism/',
                         }

C_list = [0.01, 0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]
N_list = [10.0, 30.0, 50.0, 100.0, 150.0, 
          200.0, 250.0, 300.0, 400.0, 500.0, 
          600.0, 700.0, 800.0, 900.0, 1000.0]

probability_dict = {}

subdirectory_name = 'C_{C_val}_N_{N_val}_sigma_1.0_d_4.0/'
analysis_file = 'analysis_data.txt'
num_iterations = 1000

for model, directory in target_directory_list.items():
    probability_of_stability = np.zeros([len(C_list), len(N_list)])
    for i in range(len(C_list)):
        for j in range(len(N_list)):
            analysis_file_name = directory + subdirectory_name.format(C_val=C_list[i], 
                                                                         N_val=N_list[j]) + analysis_file
            with open(analysis_file_name, 'r') as f:
                for line in f.readlines():
                    if re.match(r'probability of stability\, *', line) != None:
                        probability_of_stability[i,j] = float(line.split(',')[1])
                        
    probability_dict[model] = probability_of_stability

# %%
from matplotlib.lines import Line2D

fig,axs = plt.subplots(1,1,figsize=(6,6))

graph_dict = {'random': ['solid','k'],
             'bipartite': ['dashed', 'r'],
             }

for model in target_directory_list.keys():
    contour = axs.contour(N_list, C_list, probability_dict[model], 
                          colors=(graph_dict[model][1]), linestyles=graph_dict[model][0], 
                          levels=[0.5,])
    # axs.clabel(contour, contour.levels[::2], inline=True, fmt=[model])

lines = [Line2D([0], [0], color='k', linewidth=3, linestyle='-'),
         Line2D([0], [0], color='r', linewidth=3, linestyle='--'), 
         ]
labels = ['random', 'bipartite mutualism']
axs.legend(lines, labels)    
axs.set_xlabel(r'Number of species ($N_d$)')
axs.set_ylabel(r'Connectance ($C_d$)')
# Out:
# Text(0, 0.5, 'Connectance ($C$)')
